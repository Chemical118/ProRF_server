# %%
include("load_save.jl")
dataset_name = String(split(split(@__FILE__, '\\')[end], '.')[1])
R, X, Y, L, F, Y, PY = load_big_dataset(dataset_name);
# Out:
# Dataset : avGFP_B
# Sample : 51715
# Variable : 233

# %%
using Pandas, Seaborn

# %%
view_result(PY, Y, data_state);
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.182174

# %%
view_importance(R, L, F, show_number=30);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
tag = Vector{String}()
NL = Vector{String}()
for l in L
    nl = parse(Int, l[1:end-1])
    if nl ∈ [18, 27, 29, 57, 60, 61, 64, 65, 66, 67, 146, 148, 203, 205, 222]
        push!(tag, "Interacting\nchromophores site")
        push!(NL, "*" * l)
    else
        push!(tag, "Remains")
        push!(NL, l)
    end
end
data = Pandas.DataFrame(Dict("Feature Importance" => F, "AA type" => tag));

# %%
view_importance(R, NL, F, show_number=30)
data["all"] = ""
set_theme(style="whitegrid", palette="tab10")
violinplot(x="all", y="Feature Importance", hue="AA type", inner="quartile", data=data, split=true, bw=0.4, cut=0)
xlabel("")
display(gcf())
close("all")
matplotlib.rc_file_defaults()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
test_top5(R, F, NL)
# Out:
# MethodError: no method matching test_top5(::RF, ::Vector{Float64}, ::Vector{String})
#
# Closest candidates are:
#
#   test_top5(::AbstractRF, !Matched::Vector{String}, !Matched::Vector{Float64}) at c:\OOP\ProRF_server\load_save.jl:113
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\OOP\ProRF_server\avGFP.ipynb:1
