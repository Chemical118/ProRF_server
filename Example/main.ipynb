# %% [markdown]
# ## TDP43 analysis example
#
# Example for 16GB RAM desktop

# %%
# import moudle
using ProRF, Printf

# %%
# get data from .xlsx, .fasta, .txt file.
R = RF("Data")
X, Y, L = get_data(R, 'B', sheet="Sheet", norm=true);

# %%
# find 3 arguments for random forest
NFeat, NTree, NDepth = get_rf_value(X, Y, iter=5, memory_usage=16, max_tree=200)
@printf "Feature : %d\nTree : %d\nMax depth : %d\n" NFeat NTree NDepth
# Out:
# Find the number of feature : 1 / 5
# Find the number of feature : 2 / 5
# Find the number of feature : 3 / 5
# Find the number of feature : 4 / 5
# Find the number of feature : 5 / 5
# Find the maximum depth of the tree approximatively : 1 / 5
# Find the maximum depth of the tree approximatively : 2 / 5
# Find the maximum depth of the tree approximatively : 3 / 5
# Find the maximum depth of the tree approximatively : 4 / 5
# Find the maximum depth of the tree approximatively : 5 / 5
# Find the maximum depth of the tree accurately : 1 / 5
# Find the maximum depth of the tree accurately : 2 / 5
# Find the maximum depth of the tree accurately : 3 / 5
# Find the maximum depth of the tree accurately : 4 / 5
# Find the maximum depth of the tree accurately : 5 / 5
# Feature : 9
# Tree : 200
# Max depth : 140

# %%
# get result
M, F = get_reg_importance(R, X, Y, L, NFeat, NTree, max_depth=NDepth);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# NRMSE : 0.084519
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
